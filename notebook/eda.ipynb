# %% [markdown]
# # Early Detection of Diabetes Using Supervised Machine Learning

# %% [markdown]
# # Group members
#
# 1.   Edilawit Manaye                       UGR/7623/15
# 2.   Feven Muluken           UGR/8442/15
#
# 3.   Samrawit Alemzewd       UGR/9726/15
# 4.   Semegn Mulugeta         UGR/5660/15
#
#
# 5.   Welela Bekele           UGR/4983/15
# 6.   Yadeni Lema             UGR/0174/15

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('../data/diabetes.csv')

print(df.head())
print(df.info())
# Summary statistics for numerical features
summary_stats = df.describe()

print(summary_stats)
# Save summary statistics to CSV
summary_stats.to_csv('../results/summary_statistics.csv')
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
# ...

# %%
# Class distribution
sns.countplot(x='Outcome', data=df)
plt.title('Class Distribution')
plt.show()
# Save plot
plt.savefig("../results/class_distribution.png", dpi=300)
plt.show()

# %%
# Feature distributions
features = ['Glucose', 'BMI', 'Age']
df[features].hist(bins=20, figsize=(10, 6))
plt.suptitle('Feature Distributions')
plt.show()
# Save plot
plt.savefig("../results/feature_distributions.png", dpi=300)
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Save plot
plt.savefig("../results/correlation_heatmap.png", dpi=300)
plt.show()
